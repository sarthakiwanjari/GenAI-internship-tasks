# %%
# Install LangChain (run once)
# !pip install --upgrade langchain langchain-core

from langchain_core.prompts import PromptTemplate, ChatPromptTemplate
# Out:
# Requirement already satisfied: langchain in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (1.2.17)
# Requirement already satisfied: langchain-core in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (1.3.2)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.10 in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (from langchain) (1.1.10)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.10 in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (from langchain-core) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (from langchain-core) (0.8.0)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (from langchain-core) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (from langchain-core) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (from langchain-core) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (from langgraph<1.2.0,>=1.1.10->langchain) (4.0.3)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.12 in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (from langgraph<1.2.0,>=1.1.10->langchain) (1.0.13)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (from langgraph<1.2.0,>=1.1.10->langchain) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (from langgraph<1.2.0,>=1.1.10->langchain) (3.7.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.10->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.31.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: anyio in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (4.12.0)
# Requirement already satisfied: certifi in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.6.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\sarth\appdata\local\programs\python\python310\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (1.3.1)
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
template_1 = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms for beginners"
)

# Test
print(template_1.format(topic="Artificial Intelligence"))
# Out:
# Explain Artificial Intelligence in simple terms for beginners

# %%
multi_input_template = PromptTemplate(
    input_variables=["topic", "audience", "tone"],
    template="Explain {topic} for {audience} in a {tone} tone"
)

# Test Cases
print(multi_input_template.format(topic="AI", audience="beginners", tone="friendly"))
print(multi_input_template.format(topic="Python", audience="kids", tone="fun"))
print(multi_input_template.format(topic="Deep Learning", audience="engineers", tone="technical"))
# Out:
# Explain AI for beginners in a friendly tone
# Explain Python for kids in a fun tone
# Explain Deep Learning for engineers in a technical tone

# %%
# Teaching Template
teaching_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} clearly step by step"
)

# Interview Template
interview_template = PromptTemplate(
    input_variables=["topic"],
    template="Ask 3 questions about {topic}"
)

# Storytelling Template
story_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} as a story"
)

# Test
topic = "Machine Learning"

print(teaching_template.format(topic=topic))
print(interview_template.format(topic=topic))
print(story_template.format(topic=topic))
# Out:
# Explain Machine Learning clearly step by step
# Ask 3 questions about Machine Learning
# Explain Machine Learning as a story

# %%
chat_template = ChatPromptTemplate.from_messages([
    ("system", "You are a {role}"),
    ("user", "Explain {topic}")
])

# Test
messages = chat_template.format_messages(role="teacher", topic="Neural Networks")

for msg in messages:
    print(msg)
# Out:
# content='You are a teacher' additional_kwargs={} response_metadata={}
# content='Explain Neural Networks' additional_kwargs={} response_metadata={}

# %%
def validate_inputs(audience, tone):
    valid_audience = ["beginner", "intermediate", "expert"]
    valid_tone = ["formal", "casual", "fun"]

    if audience not in valid_audience:
        print("Invalid audience! Setting default to 'beginner'")
        audience = "beginner"

    if tone not in valid_tone:
        print("Invalid tone! Setting default to 'formal'")
        tone = "formal"

    return audience, tone

# Test
print(validate_inputs("kids", "friendly"))
# Out:
# Invalid audience! Setting default to 'beginner'
# Invalid tone! Setting default to 'formal'
# ('beginner', 'formal')

# %%
def generate_prompt(topic, audience, tone, style):

    audience, tone = validate_inputs(audience, tone)

    if style == "teaching":
        template = "Explain {topic} for {audience} in a {tone} teaching style"
    elif style == "interview":
        template = "Ask interview questions about {topic} for {audience} in a {tone} tone"
    elif style == "storytelling":
        template = "Explain {topic} for {audience} in a {tone} storytelling style"
    else:
        template = "Explain {topic} for {audience} in a {tone} tone"

    prompt = PromptTemplate(
        input_variables=["topic", "audience", "tone"],
        template=template
    )

    return prompt.format(topic=topic, audience=audience, tone=tone)

# Test
print(generate_prompt("Neural Networks", "beginner", "fun", "storytelling"))
# Out:
# Explain Neural Networks for beginner in a fun storytelling style

# %%
reusable_template = PromptTemplate(
    input_variables=["topic", "audience"],
    template="Explain {topic} for {audience}"
)

# Test with 5 inputs
inputs = [
    ("AI", "beginners"),
    ("Python", "students"),
    ("Data Science", "analysts"),
    ("ML", "engineers"),
    ("Statistics", "researchers")
]

for topic, audience in inputs:
    print(reusable_template.format(topic=topic, audience=audience))
# Out:
# Explain AI for beginners
# Explain Python for students
# Explain Data Science for analysts
# Explain ML for engineers
# Explain Statistics for researchers
